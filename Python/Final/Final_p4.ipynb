# %%
import numpy as np

data = np.random.randn(10000)

# %%
mean_value = np.mean(data)
median_value = np.median(data)
std_dev = np.std(data)

# %%
min_value = np.min(data)
max_value = np.max(data)

# %%
count_above_mean = np.sum(data > mean_value)

# %%
normalized_data = (data - min_value) / (max_value - min_value)

print(f"Mean: {mean_value}, Median: {median_value}, Std Dev: {std_dev}")
print(f"Min: {min_value}, Max: {max_value}")
print(f"Count > Mean: {count_above_mean}")
print(f"First 5 Normalized Values: {normalized_data[:5]}")
# Out:
# Mean: 0.008815249839553275, Median: 0.012144992050181283, Std Dev: 1.0068793236518585
# Min: -4.131913737843156, Max: 3.3745518272479416
# Count > Mean: 5009
# First 5 Normalized Values: [0.33379189 0.59905791 0.45462766 0.82415121 0.48290982]
